# %%
import pandas as pd
df = pd.read_csv(r"C:\\Cutomer_churn_analysis1.csv")
df.head()
# Out:
#   Customer ID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines   Unnamed: 8 OnlineSecurity  ... TechSupport StreamingTV  \
# 0  No phone service          DSL             No  ...          No          No
# 1                No          DSL            Yes  ...          No          No
# 2                No          DSL            Yes  ...          No          No
# 3  No phone service          DSL            Yes  ...         Yes          No
# 4                No  Fiber optic             No  ...          No          No
#
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'Unnamed: 8',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Unnamed: 21'],
#       dtype='str')

# %%
df.tail()
# Out:
#      Customer ID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines   Unnamed: 8 OnlineSecurity  ...  \
# 7038          Yes               Yes          DSL            Yes  ...
# 7039          Yes               Yes  Fiber optic             No  ...
# 7040           No  No phone service          DSL            Yes  ...
# 7041          Yes               Yes  Fiber optic             No  ...
# 7042          Yes                No  Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.head(10)
# Out:
#   Customer ID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines   Unnamed: 8 OnlineSecurity  ... TechSupport StreamingTV  \
# ...

# %%
df.count()
# Out:
# Customer ID         7043
# gender              7043
# SeniorCitizen       7043
# Partner             7043
# Dependents          7043
# tenure              7043
# PhoneService        7043
# MultipleLines       7043
# Unnamed: 8          7043
# OnlineSecurity      7043
# OnlineBackup        7043
# DeviceProtection    7043
# TechSupport         7043
# StreamingTV         7043
# StreamingMovies     7043
# Contract            7043
# PaperlessBilling    7043
# PaymentMethod       7043
# MonthlyCharges      7043
# TotalCharges        7043
# Churn               7043
# Unnamed: 21            3
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool

# %%
df.shape
# Out:
# (7043, 22)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   Unnamed: 8        7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.count()
# Out:
# Customer ID         7043
# gender              7043
# SeniorCitizen       7043
# Partner             7043
# Dependents          7043
# tenure              7043
# PhoneService        7043
# MultipleLines       7043
# Unnamed: 8          7043
# OnlineSecurity      7043
# OnlineBackup        7043
# DeviceProtection    7043
# TechSupport         7043
# StreamingTV         7043
# StreamingMovies     7043
# Contract            7043
# PaperlessBilling    7043
# PaymentMethod       7043
# MonthlyCharges      7043
# TotalCharges        7043
# Churn               7043
# Unnamed: 21            3
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  Unnamed: 21
# count    7043.000000  7043.000000     7043.000000     3.000000
# mean        0.162147    32.371149       64.761692     0.333333
# std         0.368612    24.559481       30.090047     0.577350
# min         0.000000     0.000000       18.250000     0.000000
# 25%         0.000000     9.000000       35.500000     0.000000
# 50%         0.000000    29.000000       70.350000     0.000000
# 75%         0.000000    55.000000       89.850000     0.500000
# max         1.000000    72.000000      118.750000     1.000000

# %%
df["PaperlessBilling"].unique()
# Out:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
df["PaperlessBilling"].nunique()
# Out:
# 2

# %%
df["Partner"].unique()
# Out:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
df["Partner"].nunique()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# Customer ID            0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# tenure                 0
# PhoneService           0
# MultipleLines          0
# Unnamed: 8             0
# OnlineSecurity         0
# OnlineBackup           0
# DeviceProtection       0
# TechSupport            0
# StreamingTV            0
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# Churn                  0
# Unnamed: 21         7040
# dtype: int64

# %%
df["TotalCharges"].unique()
# Out:
# <ArrowStringArray>
# [  '29.85',  '1889.5',  '108.15', '1840.75',  '151.65',   '820.5',  '1949.4',
#    '301.9', '3046.05', '3487.95',
#  ...
#  '2625.25', '6886.25',  '1495.1',   '743.3',  '1419.4',  '1990.5',  '7362.9',
#   '346.45',   '306.6',  '6844.5']
# Length: 6531, dtype: str

# %%
df["TotalCharges"].nunique()
# Out:
# 6531

# %%
df1=df.select_dtypes(include="object")
df1.head()
# Out:
# C:\Users\Vyshnavi\AppData\Local\Temp\ipykernel_27032\3980843343.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df1=df.select_dtypes(include="object")
#   Customer ID  gender Partner Dependents PhoneService     MultipleLines  \
# 0  7590-VHVEG  Female     Yes         No           No  No phone service
# 1  5575-GNVDE    Male      No         No          Yes                No
# 2  3668-QPYBK    Male      No         No          Yes                No
# 3  7795-CFOCW    Male      No         No           No  No phone service
# ...

# %% [markdown]
# ### gh=df[["SeniorCitizen","Partner"]]
# gh.head()

# %%
df.loc[[0,3,5],["Dependents","OnlineSecurity"]]
# Out:
#   Dependents OnlineSecurity
# 0         No             No
# 3         No            Yes
# 5         No             No

# %%
df.loc[0:5,"gender":"tenure"]
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes         No       1
# 1    Male              0      No         No      34
# 2    Male              0      No         No       2
# 3    Male              0      No         No      45
# 4  Female              0      No         No       2
# 5  Female              0      No         No       8

# %%
df.iloc[0:5,1:6]
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes         No       1
# 1    Male              0      No         No      34
# 2    Male              0      No         No       2
# 3    Male              0      No         No      45
# 4  Female              0      No         No       2

# %%
df.iloc[[6,10,15],[8,3,1]]
# Out:
#      Unnamed: 8 Partner  gender
# 6   Fiber optic      No    Male
# 10          DSL     Yes    Male
# 15  Fiber optic     Yes  Female

# %%
df.iloc[:,[8,3,1]]
# Out:
#        Unnamed: 8 Partner  gender
# 0             DSL     Yes  Female
# 1             DSL      No    Male
# 2             DSL      No    Male
# 3             DSL      No    Male
# 4     Fiber optic      No  Female
# ...           ...     ...     ...
# 7038          DSL     Yes    Male
# 7039  Fiber optic     Yes  Female
# 7040          DSL     Yes  Female
# 7041  Fiber optic     Yes    Male
# 7042  Fiber optic      No    Male
#
# [7043 rows x 3 columns]

# %%
df[::-1]
# Out:
#      Customer ID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK    Male              0      No         No      66
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# ...          ...     ...            ...     ...        ...     ...
# 4     9237-HQITU  Female              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 2     3668-QPYBK    Male              0      No         No       2
# 1     5575-GNVDE    Male              0      No         No      34
# 0     7590-VHVEG  Female              0     Yes         No       1
#
#      PhoneService     MultipleLines   Unnamed: 8 OnlineSecurity  ...  \
# 7042          Yes                No  Fiber optic            Yes  ...
# ...

# %%
df[:-1:-1]
# Out:
# Empty DataFrame
# Columns: [Customer ID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, Unnamed: 8, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn, Unnamed: 21]
# Index: []
#
# [0 rows x 22 columns]

# %%
df[:-1:]
# Out:
#      Customer ID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines   Unnamed: 8       OnlineSecurity  ...  \
# 0              No  No phone service          DSL                   No  ...
# ...

# %%
kl=[1,2,3,4,5,6,7]
kl[::-1]
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
df[::-3]
# Out:
#      Customer ID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK    Male              0      No         No      66
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7033  9767-FFLEM    Male              0      No         No      38
# 7030  0871-OPBXW  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 13    0280-XJGEX    Male              0      No         No      49
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 7     6713-OKOMC  Female              0      No         No      10
# 4     9237-HQITU  Female              0      No         No       2
# 1     5575-GNVDE    Male              0      No         No      34
#
#      PhoneService     MultipleLines   Unnamed: 8       OnlineSecurity  ...  \
# 7042          Yes                No  Fiber optic                  Yes  ...
# ...

# %%
df[::-8]
# Out:
#      Customer ID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK    Male              0      No         No      66
# 7034  0639-TSIQW  Female              0      No         No      67
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7010  0723-DRCLG  Female              1     Yes         No       1
# ...          ...     ...            ...     ...        ...     ...
# 34    3413-BMNZE    Male              1      No         No       1
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 2     3668-QPYBK    Male              0      No         No       2
#
#      PhoneService MultipleLines   Unnamed: 8 OnlineSecurity  ... TechSupport  \
# 7042          Yes            No  Fiber optic            Yes  ...         Yes
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\\Cutomer_churn_analysis1.csv")
df.head()
# Out:
#   Customer ID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines   Unnamed: 8 OnlineSecurity  ... TechSupport StreamingTV  \
# 0  No phone service          DSL             No  ...          No          No
# 1                No          DSL            Yes  ...          No          No
# 2                No          DSL            Yes  ...          No          No
# 3  No phone service          DSL            Yes  ...         Yes          No
# 4                No  Fiber optic             No  ...          No          No
#
# ...

# %%
#SCALLING TECHINES
from sklearn.preprocessing import MinMaxScaler
s_f=MinMaxScaler()
x=df[["MonthlyCharges"]]
v_s_f=s_f.fit_transform(x)
print(v_s_f)
# Out:
# [[0.11542289]
#  [0.38507463]
#  [0.35422886]
#  ...
#  [0.11293532]
#  [0.55870647]
#  [0.86965174]]

# %%
from sklearn.preprocessing import StandardScaler
s_sf=StandardScaler()
sc_d=s_sf.fit_transform(df[["MonthlyCharges"]])
sc_d
# Out:
# array([[-1.16032292],
#        [-0.25962894],
#        [-0.36266036],
#        ...,
#        [-1.1686319 ],
#        [ 0.32033821],
#        [ 1.35896134]], shape=(7043, 1))

# %%
import pandas as pd
df3=pd.read_csv(r"C:\\Cutomer_churn_analysis1.csv")

# %%
from sklearn.preprocessing import LabelEncoder
l_e=LabelEncoder()
la_d=l_e.fit_transform(df["PaperlessBilling"])
la_d
# Out:
# array([1, 0, 1, ..., 1, 1, 1], shape=(7043,))

# %%
import pandas as pd
df4=pd.read_csv(r"C:\\Cutomer_churn_analysis1.csv")

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(sparse_output=False)
ohe_d=ohe.fit_transform(df4[["gender"]])
ohe_d
jk=pd.DataFrame(ohe_d)
jk
# Out:
#         0    1
# 0     1.0  0.0
# 1     0.0  1.0
# 2     0.0  1.0
# 3     0.0  1.0
# 4     1.0  0.0
# ...   ...  ...
# 7038  0.0  1.0
# 7039  1.0  0.0
# 7040  1.0  0.0
# 7041  0.0  1.0
# 7042  0.0  1.0
#
# [7043 rows x 2 columns]
