# %%
import pandas as pd

# %%
df=pd.read_csv("supply_chain_data (1).csv")
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='str')

# %%
df.head(10)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
# 5     haircare  SKU5   1.699976            87                      147
# 6     skincare  SKU6   4.078333            48                       65
# 7    cosmetics  SKU7  42.958384            59                      426
# 8    cosmetics  SKU8  68.717597            78                      150
# 9     skincare  SKU9  64.015733            35                      980
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# ...

# %%
df.tail()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 95        7386.363944               Unknown            15          14
# 96        7698.424766            Non-binary            67           2
# 97        4370.916580                  Male            46          19
# 98        8525.952560                Female            53           1
# 99        9185.185829               Unknown            55           8
#
#     Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.shape
# Out:
# (100, 24)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    str
#  1   SKU                      100 non-null    str
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    str
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    str
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    str
# ...

# %%
df["Revenue generated"].unique()
# Out:
# array([8661.99679239, 7460.90006545, 9577.74962587, 7766.83642569,
#        2686.50515157, 2828.34874598, 7823.47655953, 8496.10381309,
#        7517.36321063, 4971.14598759, 2330.96580209, 6099.94411558,
#        2873.74144602, 4052.73841624, 8653.57092647, 5442.0867854 ,
#        6453.79796818, 2629.39643485, 9364.67350508, 2553.49558499,
#        8128.02769685, 7087.05269636, 2390.80786656, 8858.36757101,
#        9049.07786094, 2174.77705435, 3716.49332589, 2686.45722358,
#        6117.32461508, 8318.90319462, 2766.34236687, 9655.13510272,
#        9571.55048733, 5149.99835041, 9061.71089551, 6541.3293448 ,
#        7573.40245785, 2438.33993047, 9692.31804022, 1912.4656631 ,
#        5724.95935046, 5521.20525901, 1839.60942586, 5737.42559912,
#        7152.28604944, 5267.95680751, 2556.76736063, 7089.47424993,
#        7397.07100459, 8001.61320652, 5910.88538967, 9866.46545798,
#        9435.76260891, 8232.33482943, 6088.02147994, 2925.6751703 ,
# ...

# %%
df.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le_d=le.fit_transform(df['Customer demographics'])
le_d
# Out:
# array([2, 0, 3, 2, 2, 2, 1, 0, 0, 3, 2, 0, 3, 1, 2, 2, 0, 0, 3, 3, 3, 3,
#        3, 3, 1, 1, 1, 3, 0, 0, 1, 1, 3, 2, 3, 0, 0, 0, 2, 0, 0, 0, 0, 3,
#        0, 1, 2, 1, 2, 3, 0, 1, 1, 1, 2, 1, 2, 3, 2, 2, 0, 3, 3, 2, 0, 1,
#        0, 3, 2, 2, 0, 0, 2, 1, 0, 2, 1, 3, 3, 2, 3, 3, 3, 3, 3, 0, 3, 1,
#        1, 3, 2, 1, 1, 3, 3, 3, 2, 1, 0, 3])

# %%
df.select_dtypes(include=["object"])
# Out:
# C:\Users\Vyshnavi\AppData\Local\Temp\ipykernel_23072\2188799553.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include=["object"])
#    Product type    SKU Customer demographics Shipping carriers Supplier name  \
# 0      haircare   SKU0            Non-binary         Carrier B    Supplier 3
# 1      skincare   SKU1                Female         Carrier A    Supplier 3
# 2      haircare   SKU2               Unknown         Carrier B    Supplier 1
# 3      skincare   SKU3            Non-binary         Carrier C    Supplier 5
# ...

# %%
df1=pd.read_csv("sed.csv")
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df1.isnull().sum()
# Out:
# Product type               1
# SKU                        1
# Price                      0
# Availability               0
# Number of products sold    1
# Revenue generated          3
# Customer demographics      0
# Stock levels               0
# Lead times                 2
# Order quantities           1
# Shipping times             1
# Shipping carriers          2
# Shipping costs             1
# Supplier name              1
# Location                   2
# Lead time                  1
# Production volumes         1
# Manufacturing lead time    0
# Manufacturing costs        1
# Inspection results         0
# Defect rates               2
# Transportation modes       1
# Routes                     1
# Costs                      1
# dtype: int64

# %%
df1["Price"]=df1["Price"].fillna(25)

# %%
df1.head(10)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                    802.0
# 1     skincare  SKU1  14.843523            95                    736.0
# 2     haircare   NaN  11.319683            34                      8.0
# 3     skincare  SKU3  61.163343            68                     83.0
# 4     skincare  SKU4   4.805496            26                    871.0
# 5     haircare  SKU5   1.699976            87                    147.0
# 6     skincare  SKU6   4.078333            48                     65.0
# 7          NaN  SKU7  42.958384            59                    426.0
# 8    cosmetics  SKU8  68.717597            78                    150.0
# 9     skincare  SKU9  64.015733            35                    980.0
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58         7.0
# ...

# %%
df1["Stock levels"]=df1["Stock levels"].ffill()

# %%
df1.head(10)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                    802.0
# 1     skincare  SKU1  14.843523            95                    736.0
# 2     haircare   NaN  11.319683            34                      8.0
# 3     skincare  SKU3  61.163343            68                     83.0
# 4     skincare  SKU4   4.805496            26                    871.0
# 5     haircare  SKU5   1.699976            87                    147.0
# 6     skincare  SKU6   4.078333            48                     65.0
# 7          NaN  SKU7  42.958384            59                    426.0
# 8    cosmetics  SKU8  68.717597            78                    150.0
# 9     skincare  SKU9  64.015733            35                    980.0
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58         7.0
# ...

# %%
df1["Lead times"]=df1["Lead times"].bfill()

# %%
df.head(10)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
# 5     haircare  SKU5   1.699976            87                      147
# 6     skincare  SKU6   4.078333            48                       65
# 7    cosmetics  SKU7  42.958384            59                      426
# 8    cosmetics  SKU8  68.717597            78                      150
# 9     skincare  SKU9  64.015733            35                      980
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# ...

# %%
df1.shape
# Out:
# (100, 24)

# %%
df1.dropna(subset=["Revenue generated"],inplace=True)

# %%
df1.isnull().sum()
# Out:
# Product type               0
# SKU                        1
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             1
# Shipping carriers          1
# Shipping costs             1
# Supplier name              1
# Location                   2
# Lead time                  1
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        1
# Inspection results         0
# Defect rates               2
# Transportation modes       1
# Routes                     0
# Costs                      1
# dtype: int64

# %%
df2=pd.read_csv("sed.csv")
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df2.isnull().sum()
# Out:
# Product type               1
# SKU                        1
# Price                      1
# Availability               0
# Number of products sold    1
# Revenue generated          3
# Customer demographics      0
# Stock levels               2
# Lead times                 2
# Order quantities           1
# Shipping times             1
# Shipping carriers          2
# Shipping costs             1
# Supplier name              1
# Location                   2
# Lead time                  1
# Production volumes         1
# Manufacturing lead time    0
# Manufacturing costs        1
# Inspection results         0
# Defect rates               2
# Transportation modes       1
# Routes                     1
# Costs                      1
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df3=pd.read_csv("sed.csv")
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df3.dropna(how="all",inplace=True)

# %%
df3.isnull().sum()
# Out:
# Product type               1
# SKU                        1
# Price                      1
# Availability               0
# Number of products sold    1
# Revenue generated          3
# Customer demographics      0
# Stock levels               2
# Lead times                 2
# Order quantities           1
# Shipping times             1
# Shipping carriers          2
# Shipping costs             1
# Supplier name              1
# Location                   2
# Lead time                  1
# Production volumes         1
# Manufacturing lead time    0
# Manufacturing costs        1
# Inspection results         0
# Defect rates               2
# Transportation modes       1
# Routes                     1
# Costs                      1
# dtype: int64

# %%
df3.dropna(axis=1,how="all",inplace=True)
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df3.isnull().sum()
# Out:
# Product type               1
# SKU                        1
# Price                      1
# Availability               0
# Number of products sold    1
# Revenue generated          3
# Customer demographics      0
# Stock levels               2
# Lead times                 2
# Order quantities           1
# Shipping times             1
# Shipping carriers          2
# Shipping costs             1
# Supplier name              1
# Location                   2
# Lead time                  1
# Production volumes         1
# Manufacturing lead time    0
# Manufacturing costs        1
# Inspection results         0
# Defect rates               2
# Transportation modes       1
# Routes                     1
# Costs                      1
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler
